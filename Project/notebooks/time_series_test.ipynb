# %%
from discrete_time_series.src.core.coefficients import Coefficients
# Out:
# 2024-06-26 16:06:01.164 | INFO     | discrete_time_series.config:initialise:29 - Loaded module `discrete_time_series` from project directory path `/Users/mayurankv/Documents/Mayuran/Programming/Projects/Academic/Imperial College London/MSc Statistics/Dissertation/Project/modules`

# %%
coefficients = Coefficients()

# %%
coefficients.ranks
# Out:
# {'noise': 0,
#  'observations': 0,
#  'squared_residuals': 0,
#  'conditional_variances': 0}

# %%
import numpy as np

# %%
np.pad(np.array([0, 1, 2]), (0, 3))
# Out:
# array([0, 1, 2, 0, 0, 0])

# %%
a = np.array([1, 2, 3, 4])

np.convolve(np.array([[2, 4, 6, 8, 10, 12], [2, 4, 6, 8, 10, 13]]), np.array([1, 3, 5, 7]), "valid")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 3
#       1 a  = np.array([1,2,3,4])
# ----> 3 np.convolve(np.array([[2,4,6,8,10,12],[2,4,6,8,10,13]]),np.array([1,3,5,7]), "valid")
#
# File ~/Documents/Mayuran/Programming/Projects/Academic/Imperial College London/MSc Statistics/Dissertation/.venv/lib/python3.12/site-packages/numpy/core/numeric.py:834, in convolve(a, v, mode)
#     832 if len(v) == 0:
#     833     raise ValueError('v cannot be empty')
# --> 834 return multiarray.correlate(a, v[::-1], mode)
#
# ValueError: object too deep for desired array

# %%
# Out:
# array([-3.07742439,  1.34513047, -0.995072  ,  1.37460346, -1.67752708,
#         1.99964707,  1.72408301,  0.55796113,  1.82903062,  2.35618474])

# %%
# Out:
# 2024-06-26 16:46:50.752 | INFO     | discrete_time_series.config:initialise:29 - Loaded module `discrete_time_series` from project directory path `/Users/mayurankv/Documents/Mayuran/Programming/Projects/Academic/Imperial College London/MSc Statistics/Dissertation/Project/modules`

# %%
from discrete_time_series.src.core.processes.moving_average_process import MovingAverageProcess
from discrete_time_series.src.core.processes.autoregressive_process import AutoregressiveProcess
import numpy as np

a = AutoregressiveProcess([0.1])
a.simulate(num_simulations=3, initial_conditions={"observations": np.array([0.5, -0.5])})

b = MovingAverageProcess(coefficient=[0.3, 0.4])
b.simulate(3, initial_conditions={"noise": np.array([0, 0])})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 9
#       6 a.simulate(num_simulations=3, initial_conditions={"observations": np.array([0.5, -0.5])})
#       8 b = MovingAverageProcess(coefficient=[0.3,0.4])
# ----> 9 b.simulate(3, initial_conditions={"noise": np.array([0,0])})
#
# File ~/Documents/Mayuran/Programming/Projects/Academic/Imperial College London/MSc Statistics/Dissertation/Project/modules/discrete_time_series/discrete_time_series/src/core/stationary_time_series.py:79, in StationaryTimeSeries.simulate(self, num_simulations, initial_conditions, white_noise_process, seed)
#      72 white_noise = white_noise_process.simulate(
#      73 	num_simulations=num_simulations + self.coefficients.ranks["noise"],
#      74 	seed=seed,
#      75 )
#      77 components["noise"] = np.convolve(white_noise, getattr(self.coefficients, "noise"), mode="valid")
# ---> 79 simulation = np.pad(initial_conditions["observations"], pad_width=(0, num_simulations))
#      80 for step in range(num_simulations):
#      81 	simulation[step - num_simulations] = np.dot(
#      82 		simulation[step - num_simulations - self.coefficients.ranks["observations"] : step - num_simulations],
#      83 		np.flip(self.coefficients.__dict__["observations"][1:]),
#      84 	)
#
# KeyError: 'observations'
